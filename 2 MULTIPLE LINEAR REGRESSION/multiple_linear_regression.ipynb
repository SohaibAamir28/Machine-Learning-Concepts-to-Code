# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.shape
# Out:
# (100, 3)

# %%
df.head()
# Out:
#    feature1  feature2     target
# 0  0.893192 -1.488439  -0.627829
# 1 -1.082568  1.640455 -69.951714
# 2  0.343642 -1.152581 -41.282018
# 3 -0.650221  0.912055  47.612413
# 4 -1.474614 -0.728974 -75.824503

# %%
# !pip install --upgrade nbformat ipython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nbformat in c:\users\acer\appdata\roaming\python\python313\site-packages (5.10.4)
# Requirement already satisfied: ipython in c:\users\acer\appdata\roaming\python\python313\site-packages (9.8.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\acer\appdata\roaming\python\python313\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\acer\appdata\roaming\python\python313\site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\acer\appdata\roaming\python\python313\site-packages (from nbformat) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\acer\appdata\roaming\python\python313\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipython) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipython) (3.0.51)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipython) (2.19.1)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\acer\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\acer\appdata\roaming\python\python313\site-packages (from jedi>=0.18.1->ipython) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\acer\appdata\roaming\python\python313\site-packages (from jsonschema>=2.6->nbformat) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\acer\appdata\roaming\python\python313\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\acer\appdata\roaming\python\python313\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\acer\appdata\roaming\python\python313\site-packages (from jsonschema>=2.6->nbformat) (0.28.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\acer\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\acer\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (310)
# Requirement already satisfied: executing>=1.2.0 in c:\users\acer\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\acer\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\acer\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython) (0.2.3)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# MAE 53.06936612634813
# MSE 4451.850315633115
# R2 score 0.545433230722135

# %%
import numpy as np

# Create grid
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)

xGrid, yGrid = np.meshgrid(x, y)

# Prepare input for model (IMPORTANT STEP)
final = np.vstack((
    xGrid.ravel(),
    yGrid.ravel()
)).T   # shape: (100, 2)

# Predict
z_final = lr.predict(final)

# Reshape predictions for surface plot
z = z_final.reshape(10, 10)

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.add_trace(go.Surface(x = x, y = y, z =z ))

fig.show()

# %%
lr.coef_
# Out:
# array([60.42512176,  1.13863845])

# %%
lr.intercept_
# Out:
# np.float64(2.6121388826601972)
